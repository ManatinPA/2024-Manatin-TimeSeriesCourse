# %% [markdown]
# ## Анализ и прогнозирование временных рядов методами искусственного интеллекта

# %% [markdown]
# ### **Практическая работа 3. Поиск аномалий во временных рядах.**

# %% [markdown]
# #### **3.1 Поиск диссонансов с помощью алгоритма HotSAX**

# %% [markdown]
# ##### 3.1.1 Загрузка и подготовка данных

# %% [markdown]
# В данной будет использоваться временной ряд, состоящий из показаний акселерометра.
# Анализируемый временной ряд, описывает две активности человека - бег и шаг.

# %%
# !pip install scipy
# !pip install scikit-learn
# !pip install matplotlib
# Out:
# Requirement already satisfied: scipy in d:\anaconda3\envs\timeseries\lib\site-packages (1.14.1)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in d:\anaconda3\envs\timeseries\lib\site-packages (from scipy) (1.24.4)
# Requirement already satisfied: scikit-learn in d:\anaconda3\envs\timeseries\lib\site-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in d:\anaconda3\envs\timeseries\lib\site-packages (from scikit-learn) (1.24.4)
# Requirement already satisfied: scipy>=1.6.0 in d:\anaconda3\envs\timeseries\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in d:\anaconda3\envs\timeseries\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\anaconda3\envs\timeseries\lib\site-packages (from scikit-learn) (3.5.0)
# Collecting matplotlib
#   Downloading matplotlib-3.9.2-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.0-cp310-cp310-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.54.1-cp310-cp310-win_amd64.whl.metadata (167 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.7-cp310-cp310-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in d:\anaconda3\envs\timeseries\lib\site-packages (from matplotlib) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda3\envs\timeseries\lib\site-packages (from matplotlib) (24.1)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-10.4.0-cp310-cp310-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda3\envs\timeseries\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\anaconda3\envs\timeseries\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.9.2-cp310-cp310-win_amd64.whl (7.8 MB)
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.8 MB 885.6 kB/s eta 0:00:09
#    -- ------------------------------------- 0.5/7.8 MB 885.6 kB/s eta 0:00:09
#    ---- ----------------------------------- 0.8/7.8 MB 884.1 kB/s eta 0:00:08
#    ----- ---------------------------------- 1.0/7.8 MB 898.8 kB/s eta 0:00:08
#    ----- ---------------------------------- 1.0/7.8 MB 898.8 kB/s eta 0:00:08
#    ------ --------------------------------- 1.3/7.8 MB 895.5 kB/s eta 0:00:08
#    -------- ------------------------------- 1.6/7.8 MB 892.9 kB/s eta 0:00:07
#    --------- ------------------------------ 1.8/7.8 MB 891.1 kB/s eta 0:00:07
#    --------- ------------------------------ 1.8/7.8 MB 891.1 kB/s eta 0:00:07
#    ---------- ----------------------------- 2.1/7.8 MB 889.9 kB/s eta 0:00:07
#    ------------ --------------------------- 2.4/7.8 MB 889.0 kB/s eta 0:00:07
#    ------------ --------------------------- 2.4/7.8 MB 889.0 kB/s eta 0:00:07
#    ------------- -------------------------- 2.6/7.8 MB 878.0 kB/s eta 0:00:06
#    -------------- ------------------------- 2.9/7.8 MB 878.5 kB/s eta 0:00:06
#    -------------- ------------------------- 2.9/7.8 MB 878.5 kB/s eta 0:00:06
#    ---------------- ----------------------- 3.1/7.8 MB 878.9 kB/s eta 0:00:06
#    ----------------- ---------------------- 3.4/7.8 MB 875.5 kB/s eta 0:00:06
#    ------------------ --------------------- 3.7/7.8 MB 876.1 kB/s eta 0:00:05
#    ------------------ --------------------- 3.7/7.8 MB 876.1 kB/s eta 0:00:05
#    -------------------- ------------------- 3.9/7.8 MB 876.5 kB/s eta 0:00:05
#    --------------------- ------------------ 4.2/7.8 MB 880.1 kB/s eta 0:00:05
#    --------------------- ------------------ 4.2/7.8 MB 880.1 kB/s eta 0:00:05
#    ---------------------- ----------------- 4.5/7.8 MB 880.2 kB/s eta 0:00:04
#    ------------------------ --------------- 4.7/7.8 MB 877.6 kB/s eta 0:00:04
#    ------------------------- -------------- 5.0/7.8 MB 880.5 kB/s eta 0:00:04
#    ------------------------- -------------- 5.0/7.8 MB 880.5 kB/s eta 0:00:04
#    -------------------------- ------------- 5.2/7.8 MB 880.6 kB/s eta 0:00:03
#    ---------------------------- ----------- 5.5/7.8 MB 880.7 kB/s eta 0:00:03
#    ---------------------------- ----------- 5.5/7.8 MB 880.7 kB/s eta 0:00:03
#    ----------------------------- ---------- 5.8/7.8 MB 878.7 kB/s eta 0:00:03
#    ------------------------------ --------- 6.0/7.8 MB 874.7 kB/s eta 0:00:03
#    ------------------------------ --------- 6.0/7.8 MB 874.7 kB/s eta 0:00:03
#    -------------------------------- ------- 6.3/7.8 MB 877.0 kB/s eta 0:00:02
#    --------------------------------- ------ 6.6/7.8 MB 875.4 kB/s eta 0:00:02
#    ---------------------------------- ----- 6.8/7.8 MB 877.6 kB/s eta 0:00:02
#    ---------------------------------- ----- 6.8/7.8 MB 877.6 kB/s eta 0:00:02
#    ------------------------------------ --- 7.1/7.8 MB 877.8 kB/s eta 0:00:01
#    ------------------------------------- -- 7.3/7.8 MB 877.9 kB/s eta 0:00:01
#    ------------------------------------- -- 7.3/7.8 MB 877.9 kB/s eta 0:00:01
#    -------------------------------------- - 7.6/7.8 MB 878.1 kB/s eta 0:00:01
#    ---------------------------------------- 7.8/7.8 MB 874.7 kB/s eta 0:00:00
# Downloading contourpy-1.3.0-cp310-cp310-win_amd64.whl (216 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.54.1-cp310-cp310-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.2 MB 885.6 kB/s eta 0:00:02
#    --------- ------------------------------ 0.5/2.2 MB 885.6 kB/s eta 0:00:02
#    -------------- ------------------------- 0.8/2.2 MB 884.1 kB/s eta 0:00:02
#    ------------------ --------------------- 1.0/2.2 MB 883.6 kB/s eta 0:00:02
#    ----------------------- ---------------- 1.3/2.2 MB 883.4 kB/s eta 0:00:02
#    ----------------------- ---------------- 1.3/2.2 MB 883.4 kB/s eta 0:00:02
#    ---------------------------- ----------- 1.6/2.2 MB 892.9 kB/s eta 0:00:01
#    --------------------------------- ------ 1.8/2.2 MB 891.1 kB/s eta 0:00:01
#    --------------------------------- ------ 1.8/2.2 MB 891.1 kB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 878.5 kB/s eta 0:00:00
# Downloading kiwisolver-1.4.7-cp310-cp310-win_amd64.whl (55 kB)
# Downloading pillow-10.4.0-cp310-cp310-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.6 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.6 MB 882.6 kB/s eta 0:00:03
#    -------- ------------------------------- 0.5/2.6 MB 882.6 kB/s eta 0:00:03
#    ------------ --------------------------- 0.8/2.6 MB 882.6 kB/s eta 0:00:03
#    ---------------- ----------------------- 1.0/2.6 MB 882.6 kB/s eta 0:00:02
#    ---------------- ----------------------- 1.0/2.6 MB 882.6 kB/s eta 0:00:02
#    -------------------- ------------------- 1.3/2.6 MB 882.6 kB/s eta 0:00:02
#    ------------------------ --------------- 1.6/2.6 MB 882.6 kB/s eta 0:00:02
#    ---------------------------- ----------- 1.8/2.6 MB 882.6 kB/s eta 0:00:01
#    ---------------------------- ----------- 1.8/2.6 MB 882.6 kB/s eta 0:00:01
#    -------------------------------- ------- 2.1/2.6 MB 883.1 kB/s eta 0:00:01
#    ------------------------------------ --- 2.4/2.6 MB 883.0 kB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 873.3 kB/s eta 0:00:00
# Downloading pyparsing-3.1.4-py3-none-any.whl (104 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.0 cycler-0.12.1 fonttools-4.54.1 kiwisolver-1.4.7 matplotlib-3.9.2 pillow-10.4.0 pyparsing-3.1.4

# %%
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from time import time
import pandas as pd

# %%
#fixme: Путь
dataset_dir_path = Path('datasets')
data_path = dataset_dir_path/'walk_run.txt'
walk_run = np.loadtxt(data_path)[3000:4000]
data = walk_run
size_sub = 50

# %% [markdown]
# В середине временного ряда происходит смена активности (бег заменяет шаг). Нетипичным поведением, которое мы могли бы назвать диссонансами в данном ряде выступает небольшой участок между активностями, когда человек плавно увеличивает скорость шага до бега. В ходе данной работе наша задача выделить с помощью различных алгоритмов границы нашего диссонанса.

# %%
fig, ax =  plt.subplots(figsize=(14,4),ncols=1,nrows=1)
plt.plot(data[:],label='Шаг')
plt.plot(np.arange(data.shape[0]//2,data.shape[0]),data[data.shape[0]//2:],label='Бег')
plt.legend()

# %%
result={}
times={}

# %% [markdown]
# ##### 3.1.2 Реализация полного перебора

# %% [markdown]
# Приводится пример кода для нахождения топ 5 диссонансов с помощью реализации полного беребора.
# Вам необходимо добавить код для сбора времени обработки данных.

# %%
from modules.saxpy.discord import find_discords_brute_force
start = time()
discords_brute_force= np.stack(find_discords_brute_force(data[:], 50, 5))
end = time()
print(end-start)
print(discords_brute_force)
# Out:
# 274.32087683677673
# [[477.           5.88100934]
#  [412.           5.32704317]
#  [195.           3.39426635]
#  [577.           3.35554403]
#  [278.           3.10959389]]

# %% [markdown]
# ##### 3.1.3 HotSAX

# %% [markdown]
# Используя [реализацию](https://github.com/seninp/saxpy/blob/master/saxpy/hotsax.py) найдите топ 5 диссонансов ряда.
# Произведите замер времени работы.

# %%
from modules.saxpy.hotsax import find_discords_hotsax
start_hotsax = time()
discords_hotsax= np.stack(find_discords_hotsax(data[:], 50, 5))
end_hotsax = time()
print(end_hotsax-start_hotsax)
# Out:
# 6.721114158630371

# %%
discords_hotsax
# Out:
# array([[477.        ,   5.88100934],
#        [412.        ,   5.32704317],
#        [195.        ,   3.39426635],
#        [577.        ,   3.35554403],
#        [278.        ,   3.10959389]])

# %% [markdown]
# ##### 3.1.4 Визаулизация

# %% [markdown]
# Вам необходимо реализовать код позволяющий:
# 1. Вывести на одном графике ряд и его диссонансы
# 2. Столбчатую диаграмму времени работы обоих алгоритмов
#
# Постройте графики для обоих алгоритмов и сравните полученные результаты.
#
# Пример графика:
#
# ![first_graf](pics/fig_ex_1.png)

# %%
fig, ax =  plt.subplots(figsize=(14,4),ncols=1,nrows=1)
plt.plot(data[:],label='Шаг')
plt.plot(np.arange(data.shape[0]//2,data.shape[0]),data[data.shape[0]//2:],label='Бег')
for element in discords_hotsax:
    ax.add_patch(Rectangle((element[0], -10), 50, 20,alpha=0.5))
plt.title("Hotsax")

# Adding the legends
plt.show()

# %%
fig, ax =  plt.subplots(figsize=(14,4),ncols=1,nrows=1)
plt.plot(data[:],label='Шаг')
plt.plot(np.arange(data.shape[0]//2,data.shape[0]),data[data.shape[0]//2:],label='Бег')
for element in discords_brute_force:
    ax.add_patch(Rectangle((element[0], -10), 50, 20,alpha=0.5))
plt.title("BruteForce")

# Adding the legends
plt.show()

# %%
plt.bar(["brute force", "hotsax"],[end-start, end_hotsax-start_hotsax])

# Title to the plot
plt.title("Bar Chart")

# Adding the legends
plt.legend(["bar"])
plt.show()

# %%
from matplotlib.patches import Rectangle

# %% [markdown]
# ##### 3.1.5 Такси NY
#
# Произведите поиск диссонансов с помощью обоих алгоритмов на наборе данных, содержащим информацию о среднем числе пассажиров в NY. Отобразите найденные диссонансы обоими алгоритмами.

# %%
nyc_taxi = pd.read_csv(dataset_dir_path/'nyc_taxi.csv',index_col=0).values[4000:8000,0].astype(np.float64)
fig = plt.figure(figsize=(18, 4))
plt.plot(nyc_taxi)

# %% [markdown]
# # INSERT YOUR CODE

# %%
from modules.saxpy.discord import find_discords_brute_force
start = time()
discords_brute_force= np.stack(find_discords_brute_force(nyc_taxi[:], 50, 5))
end = time()
print(end-start)
print(discords_brute_force)
# Out:
# 5477.926344394684
# [[1.91000000e+03 3.52681530e+00]
#  [3.12000000e+03 3.40233164e+00]
#  [3.18300000e+03 2.64204097e+00]
#  [3.23700000e+03 2.22922775e+00]
#  [9.63000000e+02 1.61152765e+00]]

# %%
from modules.saxpy.hotsax import find_discords_hotsax
start_hotsax = time()
discords_hotsax= np.stack(find_discords_hotsax(nyc_taxi[:], 50, 5))
end_hotsax = time()
print(end_hotsax-start_hotsax)
# Out:
# 29.060433626174927

# %%
fig, ax =  plt.subplots(figsize=(14,4),ncols=1,nrows=1)
plt.plot(nyc_taxi[:])
for element in discords_hotsax:
    ax.add_patch(Rectangle((element[0], -10), 50, 40000,alpha=0.5))
plt.title("Hotsax")

# Adding the legends
plt.show()

# %%
fig, ax =  plt.subplots(figsize=(14,4),ncols=1,nrows=1)
plt.plot(nyc_taxi[:])
for element in discords_brute_force:
    ax.add_patch(Rectangle((element[0], -10), 50, 40000,alpha=0.5))
plt.title("BruteForce")

# Adding the legends
plt.show()

# %% [markdown]
# #### **3.2 Поиск диссонансов с помощью алгоритма DRAG**

# %%
# !pip install stumpy==1.11.1
# Out:
# Collecting stumpy==1.11.1
#   Downloading stumpy-1.11.1-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: numpy>=1.17 in d:\anaconda3\envs\timeseries\lib\site-packages (from stumpy==1.11.1) (1.24.4)
# Requirement already satisfied: scipy>=1.5 in d:\anaconda3\envs\timeseries\lib\site-packages (from stumpy==1.11.1) (1.14.1)
# Collecting numba>=0.54 (from stumpy==1.11.1)
#   Downloading numba-0.60.0-cp310-cp310-win_amd64.whl.metadata (2.8 kB)
# Collecting llvmlite<0.44,>=0.43.0dev0 (from numba>=0.54->stumpy==1.11.1)
#   Downloading llvmlite-0.43.0-cp310-cp310-win_amd64.whl.metadata (4.9 kB)
# Downloading stumpy-1.11.1-py3-none-any.whl (136 kB)
# Downloading numba-0.60.0-cp310-cp310-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.7 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.7 MB 882.6 kB/s eta 0:00:03
#    ------- -------------------------------- 0.5/2.7 MB 882.6 kB/s eta 0:00:03
#    ----------- ---------------------------- 0.8/2.7 MB 859.5 kB/s eta 0:00:03
#    --------------- ------------------------ 1.0/2.7 MB 867.1 kB/s eta 0:00:02
#    --------------- ------------------------ 1.0/2.7 MB 867.1 kB/s eta 0:00:02
#    ------------------- -------------------- 1.3/2.7 MB 871.6 kB/s eta 0:00:02
#    ----------------------- ---------------- 1.6/2.7 MB 873.8 kB/s eta 0:00:02
#    --------------------------- ------------ 1.8/2.7 MB 867.5 kB/s eta 0:00:01
#    --------------------------- ------------ 1.8/2.7 MB 867.5 kB/s eta 0:00:01
#    ------------------------------- -------- 2.1/2.7 MB 869.7 kB/s eta 0:00:01
#    ----------------------------------- ---- 2.4/2.7 MB 860.2 kB/s eta 0:00:01
#    ----------------------------------- ---- 2.4/2.7 MB 860.2 kB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 867.0 kB/s eta 0:00:00
# Downloading llvmlite-0.43.0-cp310-cp310-win_amd64.whl (28.1 MB)
#    ---------------------------------------- 0.0/28.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/28.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/28.1 MB ? eta -:--:--
#     --------------------------------------- 0.5/28.1 MB 882.6 kB/s eta 0:00:32
#     --------------------------------------- 0.5/28.1 MB 882.6 kB/s eta 0:00:32
#    - -------------------------------------- 0.8/28.1 MB 882.6 kB/s eta 0:00:31
#    - -------------------------------------- 1.0/28.1 MB 868.0 kB/s eta 0:00:32
#    - -------------------------------------- 1.0/28.1 MB 868.0 kB/s eta 0:00:32
#    - -------------------------------------- 1.3/28.1 MB 871.6 kB/s eta 0:00:31
#    -- ------------------------------------- 1.6/28.1 MB 873.8 kB/s eta 0:00:31
#    -- ------------------------------------- 1.8/28.1 MB 875.3 kB/s eta 0:00:31
#    -- ------------------------------------- 1.8/28.1 MB 875.3 kB/s eta 0:00:31
#    -- ------------------------------------- 2.1/28.1 MB 876.3 kB/s eta 0:00:30
#    --- ------------------------------------ 2.4/28.1 MB 860.5 kB/s eta 0:00:30
#    --- ------------------------------------ 2.4/28.1 MB 860.5 kB/s eta 0:00:30
#    --- ------------------------------------ 2.6/28.1 MB 857.9 kB/s eta 0:00:30
#    ---- ----------------------------------- 2.9/28.1 MB 860.3 kB/s eta 0:00:30
#    ---- ----------------------------------- 2.9/28.1 MB 860.3 kB/s eta 0:00:30
#    ---- ----------------------------------- 3.1/28.1 MB 862.3 kB/s eta 0:00:29
#    ---- ----------------------------------- 3.4/28.1 MB 864.2 kB/s eta 0:00:29
#    ---- ----------------------------------- 3.4/28.1 MB 864.2 kB/s eta 0:00:29
#    ----- ---------------------------------- 3.7/28.1 MB 862.1 kB/s eta 0:00:29
#    ----- ---------------------------------- 3.9/28.1 MB 863.5 kB/s eta 0:00:29
#    ----- ---------------------------------- 4.2/28.1 MB 864.8 kB/s eta 0:00:28
#    ----- ---------------------------------- 4.2/28.1 MB 864.8 kB/s eta 0:00:28
#    ------ --------------------------------- 4.5/28.1 MB 865.9 kB/s eta 0:00:28
#    ------ --------------------------------- 4.7/28.1 MB 867.0 kB/s eta 0:00:27
#    ------ --------------------------------- 4.7/28.1 MB 867.0 kB/s eta 0:00:27
#    ------- -------------------------------- 5.0/28.1 MB 865.3 kB/s eta 0:00:27
#    ------- -------------------------------- 5.2/28.1 MB 861.6 kB/s eta 0:00:27
#    ------- -------------------------------- 5.2/28.1 MB 861.6 kB/s eta 0:00:27
#    ------- -------------------------------- 5.5/28.1 MB 860.3 kB/s eta 0:00:27
#    -------- ------------------------------- 5.8/28.1 MB 861.5 kB/s eta 0:00:26
#    -------- ------------------------------- 5.8/28.1 MB 861.5 kB/s eta 0:00:26
#    -------- ------------------------------- 6.0/28.1 MB 862.4 kB/s eta 0:00:26
#    -------- ------------------------------- 6.3/28.1 MB 863.3 kB/s eta 0:00:26
#    --------- ------------------------------ 6.6/28.1 MB 862.2 kB/s eta 0:00:26
#    --------- ------------------------------ 6.6/28.1 MB 862.2 kB/s eta 0:00:26
#    --------- ------------------------------ 6.8/28.1 MB 863.0 kB/s eta 0:00:25
#    ---------- ----------------------------- 7.1/28.1 MB 863.8 kB/s eta 0:00:25
#    ---------- ----------------------------- 7.1/28.1 MB 863.8 kB/s eta 0:00:25
#    ---------- ----------------------------- 7.3/28.1 MB 864.5 kB/s eta 0:00:25
#    ---------- ----------------------------- 7.6/28.1 MB 865.2 kB/s eta 0:00:24
#    ---------- ----------------------------- 7.6/28.1 MB 865.2 kB/s eta 0:00:24
#    ----------- ---------------------------- 7.9/28.1 MB 865.8 kB/s eta 0:00:24
#    ----------- ---------------------------- 8.1/28.1 MB 864.8 kB/s eta 0:00:24
#    ----------- ---------------------------- 8.1/28.1 MB 864.8 kB/s eta 0:00:24
#    ----------- ---------------------------- 8.4/28.1 MB 864.0 kB/s eta 0:00:23
#    ------------ --------------------------- 8.7/28.1 MB 863.1 kB/s eta 0:00:23
#    ------------ --------------------------- 8.9/28.1 MB 863.8 kB/s eta 0:00:23
#    ------------ --------------------------- 8.9/28.1 MB 863.8 kB/s eta 0:00:23
#    ------------- -------------------------- 9.2/28.1 MB 863.0 kB/s eta 0:00:22
#    ------------- -------------------------- 9.4/28.1 MB 863.5 kB/s eta 0:00:22
#    ------------- -------------------------- 9.4/28.1 MB 863.5 kB/s eta 0:00:22
#    ------------- -------------------------- 9.7/28.1 MB 864.1 kB/s eta 0:00:22
#    -------------- ------------------------- 10.0/28.1 MB 863.4 kB/s eta 0:00:22
#    -------------- ------------------------- 10.0/28.1 MB 863.4 kB/s eta 0:00:22
#    -------------- ------------------------- 10.2/28.1 MB 863.9 kB/s eta 0:00:21
#    -------------- ------------------------- 10.5/28.1 MB 864.4 kB/s eta 0:00:21
#    --------------- ------------------------ 10.7/28.1 MB 864.8 kB/s eta 0:00:21
#    --------------- ------------------------ 10.7/28.1 MB 864.8 kB/s eta 0:00:21
#    --------------- ------------------------ 11.0/28.1 MB 864.2 kB/s eta 0:00:20
#    ---------------- ----------------------- 11.3/28.1 MB 862.5 kB/s eta 0:00:20
#    ---------------- ----------------------- 11.3/28.1 MB 862.5 kB/s eta 0:00:20
#    ---------------- ----------------------- 11.5/28.1 MB 863.0 kB/s eta 0:00:20
#    ---------------- ----------------------- 11.8/28.1 MB 862.4 kB/s eta 0:00:19
#    ---------------- ----------------------- 11.8/28.1 MB 862.4 kB/s eta 0:00:19
#    ----------------- ---------------------- 12.1/28.1 MB 862.8 kB/s eta 0:00:19
#    ----------------- ---------------------- 12.3/28.1 MB 862.3 kB/s eta 0:00:19
#    ----------------- ---------------------- 12.3/28.1 MB 862.3 kB/s eta 0:00:19
#    ----------------- ---------------------- 12.6/28.1 MB 863.7 kB/s eta 0:00:18
#    ------------------ --------------------- 12.8/28.1 MB 864.1 kB/s eta 0:00:18
#    ------------------ --------------------- 12.8/28.1 MB 864.1 kB/s eta 0:00:18
#    ------------------ --------------------- 13.1/28.1 MB 863.5 kB/s eta 0:00:18
#    ------------------- -------------------- 13.4/28.1 MB 863.9 kB/s eta 0:00:18
#    ------------------- -------------------- 13.6/28.1 MB 863.4 kB/s eta 0:00:17
#    ------------------- -------------------- 13.6/28.1 MB 863.4 kB/s eta 0:00:17
#    ------------------- -------------------- 13.9/28.1 MB 863.8 kB/s eta 0:00:17
#    -------------------- ------------------- 14.2/28.1 MB 863.3 kB/s eta 0:00:17
#    -------------------- ------------------- 14.2/28.1 MB 863.3 kB/s eta 0:00:17
#    -------------------- ------------------- 14.4/28.1 MB 863.7 kB/s eta 0:00:16
#    -------------------- ------------------- 14.7/28.1 MB 863.2 kB/s eta 0:00:16
#    -------------------- ------------------- 14.7/28.1 MB 863.2 kB/s eta 0:00:16
#    --------------------- ------------------ 14.9/28.1 MB 862.8 kB/s eta 0:00:16
#    --------------------- ------------------ 15.2/28.1 MB 863.1 kB/s eta 0:00:15
#    --------------------- ------------------ 15.2/28.1 MB 863.1 kB/s eta 0:00:15
#    --------------------- ------------------ 15.5/28.1 MB 862.7 kB/s eta 0:00:15
#    ---------------------- ----------------- 15.7/28.1 MB 863.0 kB/s eta 0:00:15
#    ---------------------- ----------------- 16.0/28.1 MB 863.3 kB/s eta 0:00:15
#    ---------------------- ----------------- 16.0/28.1 MB 863.3 kB/s eta 0:00:15
#    ----------------------- ---------------- 16.3/28.1 MB 862.9 kB/s eta 0:00:14
#    ----------------------- ---------------- 16.5/28.1 MB 863.2 kB/s eta 0:00:14
#    ----------------------- ---------------- 16.5/28.1 MB 863.2 kB/s eta 0:00:14
#    ----------------------- ---------------- 16.8/28.1 MB 863.5 kB/s eta 0:00:14
#    ------------------------ --------------- 17.0/28.1 MB 863.2 kB/s eta 0:00:13
#    ------------------------ --------------- 17.0/28.1 MB 863.2 kB/s eta 0:00:13
#    ------------------------ --------------- 17.3/28.1 MB 864.1 kB/s eta 0:00:13
#    ------------------------ --------------- 17.6/28.1 MB 862.4 kB/s eta 0:00:13
#    ------------------------- -------------- 17.8/28.1 MB 862.7 kB/s eta 0:00:12
#    ------------------------- -------------- 17.8/28.1 MB 862.7 kB/s eta 0:00:12
#    ------------------------- -------------- 18.1/28.1 MB 863.0 kB/s eta 0:00:12
#    -------------------------- ------------- 18.4/28.1 MB 863.3 kB/s eta 0:00:12
#    -------------------------- ------------- 18.4/28.1 MB 863.3 kB/s eta 0:00:12
#    -------------------------- ------------- 18.6/28.1 MB 863.5 kB/s eta 0:00:12
#    -------------------------- ------------- 18.9/28.1 MB 862.6 kB/s eta 0:00:11
#    -------------------------- ------------- 18.9/28.1 MB 862.6 kB/s eta 0:00:11
#    --------------------------- ------------ 19.1/28.1 MB 862.8 kB/s eta 0:00:11
#    --------------------------- ------------ 19.4/28.1 MB 863.1 kB/s eta 0:00:11
#    --------------------------- ------------ 19.4/28.1 MB 863.1 kB/s eta 0:00:11
#    --------------------------- ------------ 19.7/28.1 MB 862.8 kB/s eta 0:00:10
#    ---------------------------- ----------- 19.9/28.1 MB 863.0 kB/s eta 0:00:10
#    ---------------------------- ----------- 20.2/28.1 MB 862.7 kB/s eta 0:00:10
#    ---------------------------- ----------- 20.2/28.1 MB 862.7 kB/s eta 0:00:10
#    ----------------------------- ---------- 20.4/28.1 MB 863.0 kB/s eta 0:00:09
#    ----------------------------- ---------- 20.7/28.1 MB 862.6 kB/s eta 0:00:09
#    ----------------------------- ---------- 20.7/28.1 MB 862.6 kB/s eta 0:00:09
#    ----------------------------- ---------- 21.0/28.1 MB 862.9 kB/s eta 0:00:09
#    ----------------------------- ---------- 21.0/28.1 MB 862.9 kB/s eta 0:00:09
#    ------------------------------ --------- 21.2/28.1 MB 859.8 kB/s eta 0:00:09
#    ------------------------------ --------- 21.5/28.1 MB 858.5 kB/s eta 0:00:08
#    ------------------------------ --------- 21.5/28.1 MB 858.5 kB/s eta 0:00:08
#    ------------------------------ --------- 21.8/28.1 MB 858.8 kB/s eta 0:00:08
#    ------------------------------- -------- 22.0/28.1 MB 858.5 kB/s eta 0:00:08
#    ------------------------------- -------- 22.3/28.1 MB 858.8 kB/s eta 0:00:07
#    ------------------------------- -------- 22.3/28.1 MB 858.8 kB/s eta 0:00:07
#    -------------------------------- ------- 22.5/28.1 MB 859.1 kB/s eta 0:00:07
#    -------------------------------- ------- 22.8/28.1 MB 859.4 kB/s eta 0:00:07
#    -------------------------------- ------- 22.8/28.1 MB 859.4 kB/s eta 0:00:07
#    -------------------------------- ------- 23.1/28.1 MB 859.6 kB/s eta 0:00:06
#    --------------------------------- ------ 23.3/28.1 MB 859.4 kB/s eta 0:00:06
#    --------------------------------- ------ 23.3/28.1 MB 859.4 kB/s eta 0:00:06
#    --------------------------------- ------ 23.6/28.1 MB 859.6 kB/s eta 0:00:06
#    --------------------------------- ------ 23.9/28.1 MB 859.9 kB/s eta 0:00:05
#    ---------------------------------- ----- 24.1/28.1 MB 860.1 kB/s eta 0:00:05
#    ---------------------------------- ----- 24.1/28.1 MB 860.1 kB/s eta 0:00:05
#    ---------------------------------- ----- 24.4/28.1 MB 859.9 kB/s eta 0:00:05
#    ----------------------------------- ---- 24.6/28.1 MB 860.1 kB/s eta 0:00:05
#    ----------------------------------- ---- 24.6/28.1 MB 860.1 kB/s eta 0:00:05
#    ----------------------------------- ---- 24.9/28.1 MB 859.4 kB/s eta 0:00:04
#    ----------------------------------- ---- 25.2/28.1 MB 859.7 kB/s eta 0:00:04
#    ----------------------------------- ---- 25.2/28.1 MB 859.7 kB/s eta 0:00:04
#    ------------------------------------ --- 25.4/28.1 MB 859.9 kB/s eta 0:00:04
#    ------------------------------------ --- 25.7/28.1 MB 859.7 kB/s eta 0:00:03
#    ------------------------------------ --- 25.7/28.1 MB 859.7 kB/s eta 0:00:03
#    ------------------------------------ --- 26.0/28.1 MB 859.5 kB/s eta 0:00:03
#    ------------------------------------- -- 26.2/28.1 MB 859.9 kB/s eta 0:00:03
#    ------------------------------------- -- 26.5/28.1 MB 859.5 kB/s eta 0:00:02
#    ------------------------------------- -- 26.5/28.1 MB 859.5 kB/s eta 0:00:02
#    -------------------------------------- - 26.7/28.1 MB 859.9 kB/s eta 0:00:02
#    -------------------------------------- - 27.0/28.1 MB 859.9 kB/s eta 0:00:02
#    -------------------------------------- - 27.0/28.1 MB 859.9 kB/s eta 0:00:02
#    -------------------------------------- - 27.3/28.1 MB 859.9 kB/s eta 0:00:02
#    ---------------------------------------  27.5/28.1 MB 859.9 kB/s eta 0:00:01
#    ---------------------------------------  27.5/28.1 MB 859.9 kB/s eta 0:00:01
#    ---------------------------------------  27.8/28.1 MB 859.5 kB/s eta 0:00:01
#    ---------------------------------------  28.0/28.1 MB 859.5 kB/s eta 0:00:01
#    ---------------------------------------- 28.1/28.1 MB 855.4 kB/s eta 0:00:00
# Installing collected packages: llvmlite, numba, stumpy
# Successfully installed llvmlite-0.43.0 numba-0.60.0 stumpy-1.11.1

# %%
import stumpy
from stumpy import core, config
from stumpy.scrump import _prescrump

# %% [markdown]
# Как мы помним из лекций:
#
# **Диапазонный диссонанс** – подпоследовательность ряда, расстояние от которой до ее ближайшего соседа не ниже заданного порога.
#
# Основными параметрами при поисках диссонансов являются:
# - $m$ - длина диссонанса
# - $r$ - пороговое значение расстояния подпоследовательности ряда, до его ближайшего соседа

# %%
from modules.drag import find_candidates, DRAG

# %% [markdown]
# Для поиска диссонансов в данной части практической работы мы воспользуемся алгоритмом **DRAG (Discord Range Aware Gathering)**.
# Для начала воспользуемся данным алгоритмом, чтобы найти диссонансы в наборе данных содержащем активность человека.

# %%
data = walk_run

# %% [markdown]
# Длину искомого диссонанса, как и для предыдущих алгоритмов, мы установим равно 50 точек.
# Пороговое значение мы установим равным большим, чтобы узнать, как алгоритм отреагирует на большие значения данного параметра.

# %%
m = 50 
r = 10
idxs, _, _ = DRAG(data,m,r)
print(f'Колличество найденных диссонансов: {len(idxs)}')
# Out:
# Колличество найденных диссонансов: 0

# %% [markdown]
# Как вы можете видеть мы установили слишком большое пороговое значение, алгоритму не удалось выделить ни одного диссонанса. Попробуем уменьшить пороговое значение до 1, чтобы улучшить результат.

# %%
m = 50 
r = 1
idxs, _, _ = DRAG(data, m, r)
print(f'Колличество найденных диссонансов: {len(idxs)}')
# Out:
# Колличество найденных диссонансов: 50

# %%
m = 50 
r = 3
idxs, _, _ = DRAG(data, m, r)
print(f'Колличество найденных диссонансов: {len(idxs)}')
# Out:
# Колличество найденных диссонансов: 9

# %% [markdown]
# При такой комбинации параметров, улучшить ситуацию не получилось. Алгоритм выделил слишком большое количество диссонансов, часть которых является ложными диссонансами и не будут информативными для нас.

# %% [markdown]
# Произведите подобные эксперименты с набором данных такси NY. Постройте графики демонстрирующие найденные диссонансы. Пример Графика:
# ![second-graph](pics/fig_ex_2.png)

# %%
m = 50 
r = 3
idxs, _, _ = DRAG(nyc_taxi, m, r)
print(f'Колличество найденных диссонансов: {len(idxs)}')
# Out:
# Колличество найденных диссонансов: 4

# %%
print(idxs)
# Out:
# [1910, 1952, 3120, 1934]

# %%
fig, ax =  plt.subplots(figsize=(14,4),ncols=1,nrows=1)
plt.plot(nyc_taxi[:])
for element in idxs:
    ax.add_patch(Rectangle((element, -10), 50, 40000,alpha=0.5))
plt.title("DRAG")

# Adding the legends
plt.show()

# %% [markdown]
# Чтобы разобраться, почему так происходит и как работает данный алгоритм, ниже мы реализуем все этапы алгоритма DRAG.
#
# Как мы помним из лекций алгоритм DRAG содержит два этапа:
#
# 1. Отбор - За одно сканирование ряда сформировать множество кандидатов в диссонансы.
# 2. Очистка - За одно сканирование ряда отбросить кандидатов, которые являются ложными диссонансами.

# %% [markdown]
# ##### 3.2.1 Отбор кандидатов
#
# Первым этапом обработки данных является отбор множества потенциальных кандидатов. Мы выбираем из всего множества подпоследовательностей ряда такие, для которых расстояние до правых ближайших соседей больше параметра $r$.

# %%
#выбирем более реальное значение для порога
r = 3

# %%
T, M_T, Σ_T = core.preprocess(data, m)
#формируем массив длинной равной длине  исходного ряда - m + 1, 
#элемент массива является истинным, 
#в том случае если подпоследовательность является потенциальным кандидатом
is_cands = find_candidates(T, m, M_T, Σ_T, r, init_cands=None, right=True)
#находим индексы потенциальных кандидатов
cand_index = np.flatnonzero(is_cands)

# %%
print(f'{len(cand_index)} {len(cand_index)/len(data)*100} %')
# Out:
# 113 11.3 %

# %%
cand_index
# Out:
# array([ 34, 183, 185, 186, 190, 193, 194, 195, 267, 268, 269, 270, 271,
#        272, 273, 274, 276, 277, 278, 279, 280, 341, 342, 345, 346, 407,
#        409, 410, 411, 412, 413, 414, 423, 426, 429, 440, 441, 442, 443,
#        444, 445, 446, 447, 448, 449, 450, 451, 452, 453, 454, 455, 456,
#        457, 458, 459, 460, 461, 462, 465, 466, 467, 469, 471, 472, 473,
#        474, 475, 476, 477, 478, 479, 480, 481, 482, 483, 484, 485, 486,
#        487, 577, 578, 623, 624, 664, 692, 699, 700, 701, 702, 703, 704,
#        705, 706, 707, 708, 709, 710, 711, 714, 715, 716, 717, 718, 754,
#        755, 912, 913, 914, 915, 917, 919, 921, 940], dtype=int64)

# %% [markdown]
# Во время отбора кандидатов нам удалось выделить около 113 подпоследовательностей(около 11.3%), которые мы бы могли назвать потенциальными диссонансами.
# Это большой процент, который не может нас устраивать как конечный результат.
# Если посмотреть на рисунок ниже, мы увидим, что большая часть потенциальных диссонансов расположена в районе смены активности.
# К сожалению пресутсвуют и ложные диссонансы, которые случайным образом попали в данный список.

# %% [markdown]
# Сформируйте график найденных диссонансов

# %%
fig, ax =  plt.subplots(figsize=(14,4),ncols=1,nrows=1)
plt.plot(data[:])
for element in cand_index:
    ax.add_patch(Rectangle((element, -10), 50, 40,alpha=0.1))
plt.title("DRAG")

# Adding the legends
plt.show()

# %% [markdown]
# ##### 3.2.2 Очистка кандидатов
# Как уже упоминалось выше, 11.3% слишком большой процент диссонансов.
# Для уменьшения числа потенциальных кандидатов произведем очистку от ложных диссонансов, путем сравнения расстояния до левых ближайших соседей потенциальных диссонансов с порогом $r$.

# %%
is_cands = find_candidates(T, m, M_T, Σ_T, r, init_cands=is_cands, right=False)
cands = np.flatnonzero(is_cands)

# %%
len(cands)/len(data)*100
# Out:
# 2.9000000000000004

# %% [markdown]
# Сформируйте график найденных диссонансов

# %%
fig, ax =  plt.subplots(figsize=(14,4),ncols=1,nrows=1)
plt.plot(data[:])
for element in cands:
    ax.add_patch(Rectangle((element, -10), 50, 40,alpha=0.1))
plt.title("DRAG")

# Adding the legends
plt.show()

# %% [markdown]
# Нам удалось сократить число диссонансов до 2.9%. Если проанализировать рисунок, то можно заметить, что большая их часть является тривиальными повторениями подпоследовательности в области смены активности. На следующем шаге избавимся от них.

# %%
from modules.drag import refine_candidates
discords_idx, discords_dist, discords_nn_idx = refine_candidates(T, m, M_T, Σ_T, is_cands)
len(discords_idx)/len(data)*100
# Out:
# 0.8999999999999999

# %% [markdown]
# Сформируйте график найденных диссонансов

# %%
fig, ax =  plt.subplots(figsize=(14,4),ncols=1,nrows=1)
plt.plot(data[:])
for element in discords_idx:
    ax.add_patch(Rectangle((element, -10), 50, 40,alpha=0.5))
plt.title("DRAG")

# Adding the legends
plt.show()

# %% [markdown]
# ##### 3.2.3 Подбор параметров

# %% [markdown]
# Реализуйте перебор параметров $m$ и $r$. Подберете параметры таким образом, чтобы алгоритм обнаружил только те диссонансы, которые связаны со сменой активности. Сделайте вывод о том, как эти параметры влияют на качество работы модели.
# Подберите оптимальные параметры алгоритма для набора данных такси NY.
# Визуализируйте результаты для разных комбинаций. Сделайте выводы.

# %%
r = 1
T, M_T, Σ_T = core.preprocess(nyc_taxi, m)
#формируем массив длинной равной длине  исходного ряда - m + 1, 
#элемент массива является истинным, 
#в том случае если подпоследовательность является потенциальным кандидатом
is_cands = find_candidates(T, m, M_T, Σ_T, r, init_cands=None, right=True)
is_cands = find_candidates(T, m, M_T, Σ_T, r, init_cands=is_cands, right=False)
#находим индексы потенциальных кандидатов
discords_idx, discords_dist, discords_nn_idx = refine_candidates(T, m, M_T, Σ_T, is_cands)
cand_index = np.flatnonzero(is_cands)

# %%
fig, ax =  plt.subplots(figsize=(14,4),ncols=1,nrows=1)
plt.plot(nyc_taxi[:])
for element in discords_idx:
    ax.add_patch(Rectangle((element, -10), 50, 40000,alpha=0.2))
plt.title("NYC Taxi")

# Adding the legends
plt.show()

# %%
Длина диссонанса должна быть не больше длины цикла. При этом пороговое значение расстояния можно только подобрать для конкретного датасета.

# %% [markdown]
# #### **3.3 Поиск диссонансов с помощью алгоритма Merlin**

# %% [markdown]
# Как мы уже выяснили подбирать параметры для DRAG простым перебором не очень удобно. Для оптимизации данного процесса в статье [1] был предложен алгоритм Merlin для оптимального поиска подходящего порогового значения.
#
# Условно мы можем разделить поиск диссонансов на три шага:
#
# 1. Поиск диссонансов минимальной длинны $minL$. На данном шаге $r = 2\sqrt{minL}$.
# 2. Поиск диссонансов следующих четырех длин. На данном шаге $r = 0.99 \cdot nndist_{m-1}$. Где $nndist_{m-1}$ - расстояние до ближайшего соседа предыдущего найденного диссонанса.
# 3. Поиск диссонансов всех
# оставшихся дли. $r = \mu - 2 \sigma$. Средние значение и стандартное отклонение вычисляются из расстояний 5 предыдущих диссонансов. н
#
# [1] Nakamura T., Imamura M., Mercer R., Keogh E.J. MERLIN: parameter-free discovery of arbitrary length anomalies in massive time series archives. 20th IEEE Int. Conf. on Data Mining, ICDM 2020, Sorrento, Italy, November 17-20, 2020. pp. 1190-1195. IEEE (2020). https://doi.org/10.1109/ICDM50108.2020.00147

# %% [markdown]
# ##### 3.3.1 Поиск диссонансов минимальной длинны

# %% [markdown]
# Вспомнил последовательность действий первого шага алгоритма:
# ![merlin-part-first](pics/first_part.png)
#
# В данной работе мы внесем небольшое изменение, мы будем считать, что подпоследовательность может быть диссонансом только в том случае, если больше 75% точек, не входят в состав других диссонансов.

# %%
T = walk_run
m = 50
# сформируем массив метод для потенциальных кандидатов в диссонансы.
# после каждого найденного диссонанса, 
# мы будем исключать окружающие его подпоследовательности из числа потенциальных кандидатов,
# путем замены значений их меток на false
excl_zone = int(np.ceil(m / 4))
include = np.ones(len(T)-m+1, dtype=bool)
# Количество диссонансов, которые мы будем искать
topK = 10

# %%
dis_idx = -np.ones((topK))
dis_nnDist = -np.ones((topK))
dis_nn_idx = np.full((topK),-np.inf)
#первое прближение r
r = 2*np.sqrt(m)
minL = m
maxL = int(m+np.ceil(m*0.1))
#количество найденных диссонасов
cound_find_dis = 0

while dis_nnDist[cound_find_dis-1]<0 and cound_find_dis<topK:
    result = DRAG(data=T,m=minL,r=r, include =include)
    for diss, nnDist, nn in zip(*result):
        dis_idx[cound_find_dis] = diss
        dis_nnDist[cound_find_dis] = nnDist
        dis_nn_idx[cound_find_dis] = nn
        #исключаем окружающие найденный диссонас 
        #подпоследовательности и числа потенциальных диссонасов
        core.apply_exclusion_zone(include, diss, excl_zone, False)
        cound_find_dis+=1
        if cound_find_dis>=topK:
            break
    r*=0.5

# %%
maxL
# Out:
# 55

# %%
print('Количество найденных на первом этапе диссонансов:', cound_find_dis)
# Out:
# Количество найденных на первом этапе диссонансов: 2

# %% [markdown]
# На первом шаге нам удалось выделить 2 диссонанса из 10 требуемых.
# Реализуйте, оставшиеся шаги алгоритма, чтобы найти оставшиеся диссонансы.
#
# ![merlin-part-first](pics/second_part.png)

# %%
# INSERT YOUR CODE

# %% [markdown]
# Найдите диссонансы набора такси NY. Визуализируйте найденные диссонансы для обоих наборов данных, сравните с результатами остальных методов.

# %%
# INSERT YOUR CODE
